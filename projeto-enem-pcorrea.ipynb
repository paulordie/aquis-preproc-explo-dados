# %% [markdown]
# # Especificação do Projeto Final - Módulo 4 Pós UEA
#
# 1. O trabalho será feito por equipe. [ok]
#
#     Equipe: Everton, Maisa, Paulo e Thiago
#
#
# 2. Vocês vão definir questões que sejam interessantes para um negócio e que para ser respondidas precisem da Ciência dos Dados. O negócio pode ser qualquer área de atuação. [ok]
#
#    Área de atuação: Educação no Ensino Médio do Brasil
#
#    **Como está o desempenho dos alunos brasileiros segundo o ENEM 2019? Média das notas do brasil e média por região**
#
#    **Qual região do país os alunos obtiveram as melhores notas?**
#
#    **Qual escola estuda o aluno que tirou a maior nota?**
#
#    **Quais as melhores escolas de Manaus?**
#
#    **Quais as piores escolas de Manaus?**
#
#    **Qual a faixa de renda familiar dos alunos que obtiveram as menores notas?**
#
#    **Qual a faixa de renda familiar dos alunos que obtiveram as maiores notas?**
#
#    **Qual a area de conhecimento (Ciências naturais, Matemática, Linguagens...) que os alunos obtiveram as menores notas?**
#
#
# 3. Coleta de Dados. Fazer a coleta de dados das fontes de dados disponíveis (pode ser uma fonte ou várias). Avaliando se têm dados para responder as questões identificadas no ponto 2. Deve avaliar a qualidade dos dados a partir das dimensões de qualidade. [ok]
#
#     Fonte 1: INSTITUTO NACIONAL DE ESTUDOS E PESQUISAS EDUCACIONAIS ANÍSIO TEIXEIRA. Microdados do Enem 2019. Brasília: Inep, 2019. Disponível em: <https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem>. Acessado em 21/02/2021.
#
#     Fonte 2: INSTITUTO NACIONAL DE ESTUDOS E PESQUISAS EDUCACIONAIS ANÍSIO TEIXEIRA. Catálogo de Escolas. Brasília: Inep, 2019. Disponível em: <https://inepdata.inep.gov.br/analytics/saw.dll?dashboard>. Acessado em 21/02/2021.
#
#
# 4. Aplicar métodos de pré-processamento de dados estudados, explicando para que é cada método (ao aplicar os métodos poderão ter algumas respostas). Obter um dataset de qualidade pronto para aplicar método de ML.
#
#
#
# 5. Explorar seus dados, para responder algumas das questões definidas no ponto 2. Outras questões poderão ser só respondidas depois de usar métodos de ML.
#
#
# 6. Todos os documentos do projeto deveram ser postados no GitHub, e deverá ser feita uma apresentação na última aula da disciplina.
# 7. Seu projeto vai ser avaliado por outros Equipes e a nota final do projeto vai levar em conta as avaliações feita pelas outras equipes e a avaliação feita pelo professor.

# %%
import pandas as pd

# %%
microdados_enem2019 = pd.read_csv('../DADOS/MICRODADOS_ENEM_2019.csv',sep=';',encoding='ISO-8859-1')

# %%
microdados_enem2019.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA     NO_MUNICIPIO_RESIDENCIA  \
# 0  190001004627    2019                  1506807                    Santarém
# 1  190001004628    2019                  1504059                  Mãe do Rio
# 2  190001004629    2019                  1505502                 Paragominas
# 3  190001004630    2019                  1507706  São Sebastião da Boa Vista
# 4  190001004631    2019                  1503903                      Juruti
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                15               PA        21       M                1
# 1                15               PA        16       F                1
# 2                15               PA        18       F                1
# 3                15               PA        23       M                0
# 4                15               PA        23       M                1
#
# ...

# %%
microdados_enem2019
# Out:
#          NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# 0        190001004627    2019                  1506807
# 1        190001004628    2019                  1504059
# 2        190001004629    2019                  1505502
# 3        190001004630    2019                  1507706
# 4        190001004631    2019                  1503903
# ...               ...     ...                      ...
# 5095265  190006129589    2019                  2928604
# 5095266  190006129590    2019                  2927408
# 5095267  190006129591    2019                  2931806
# 5095268  190006129592    2019                  2927408
# 5095269  190006129593    2019                  2914802
#
#             NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  \
# 0                          Santarém                15               PA
# 1                        Mãe do Rio                15               PA
# 2                       Paragominas                15               PA
# ...

# %%
cols = microdados_enem2019.columns.tolist()

# %%
cols
save_cols = []
for x in cols:
    save_cols.append(x)
    
print(save_cols)
# Out:
# ['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA', 'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA', 'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO', 'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ', 'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA', 'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL', 'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA', 'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE', 'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR', 'IN_SEM_RECURSO', 'IN_BRAILLE', 'IN_AMPLIADA_24', 'IN_AMPLIADA_18', 'IN_LEDOR', 'IN_ACESSO', 'IN_TRANSCRICAO', 'IN_LIBRAS', 'IN_TEMPO_ADICIONAL', 'IN_LEITUR
# ...

# %%
escolas = pd.read_csv('../escolas.csv',sep=';',encoding='utf-8')

# %%
escolas
# Out:
#                                  Restrição de Atendimento  \
# 0       ESCOLA ATENDE EXCLUSIVAMENTE ALUNOS COM DEFICI...
# 1       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 2       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 3       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 4       ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# ...                                                   ...
# 222931                                  ESCOLA PARALISADA
# 222932  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 222933  ESCOLA EM FUNCIONAMENTO E SEM RESTRIÇÃO DE ATE...
# 222934                                  ESCOLA PARALISADA
# 222935                                  ESCOLA PARALISADA
#
#                                                  Escola  Código INEP  UF  \
# 0                    EEEE ABNAEL MACHADO DE LIMA - CENE     11000023  RO
# 1                              EMEIEF PEQUENOS TALENTOS     11000040  RO
# ...

# %%
cod_nome_escola = escolas[['Código INEP','Escola']]

# %%
cod_nome_escola[cod_nome_escola['Escola'] == 'FUNDACAO MATIAS MACHLINE']
# Out:
#       Código INEP                    Escola
# 4601     13031767  FUNDACAO MATIAS MACHLINE

# %%
import pandas as pd
import numpy as np
import statistics as st
import seaborn as se
import statsmodels.stats.proportion as smp
from scipy import stats
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
def meanAndStandar(x):
    print("média=",round(st.mean(x),3))
    print("desvio-padrão=",round(st.stdev(x),3))
    return (st.mean(x),3), (st.stdev(x),3)

# %%
def intervConfianca(x):
    print("Intervalo de Confiança ao nível de 95% para média quando a variância é desconhecida")
    inf,sup = norm.interval(0.95, st.mean(x), st.stdev(x)/np.sqrt(len(x)))
    print ('Limite inferior 95%:', round(inf,3))
    print ('Limite superior 95%:', round(sup,3))

# %%
def countPlot(xcolumns,df):
    se.countplot(x=xcolumns,data=df)

# %%
def checkNormalDistribution(var):
    fig, ax = plt.subplots()
    stats.probplot(var, fit=True,   plot=ax)
    plt.show()

# %%
def boxPlotText(df,txt):
    #bdenade['conceito'] and text
    se.boxplot(df).set_title(txt)

# %%
def shapeFindNum(df,amostra,target):
    result = df.loc[amostra == target]
    result.shape

# %%
def grafNormalized(df,txt):
    se.distplot(df).set_title(txt)

# %%
from scipy import stats
import pandas as pd

# %%
# !pip install plotly

# %%
import plotly.graph_objects as go
import plotly.offline as py

# %%
def funcScatter(df1_col,df2_col):
    track = go.Scatter(x = df1_col,y = df2_col,mode = 'markers')
    return track

# %%
def plotDisper(track):
    data = [track]
    py.iplot(data)

# %%
def calCov(df):
    df.cov()

# %%
#'pearson','kendall',
def calCorr(df,_method):
    df.corr(method=_method)

# %%
# meanAndStandar(microdados_enem2019['NU_IDADE'])

# %%
# df_manaus = microdados_enem2019[microdados_enem2019['NO_MUNICIPIO_ESC']=='Manaus']
# df_manaus

# %%
meanAndStandar(df_manaus['NU_IDADE'])
# Out:
# média= 18.466
# desvio-padrão= 3.267

# %%
df_manaus_small = df_manaus.copy()
df_manaus_small.drop(['IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ', 'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA', 'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL', 'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA', 'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE', 'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR', 'IN_SEM_RECURSO', 'IN_BRAILLE', 'IN_AMPLIADA_24', 'IN_AMPLIADA_18', 'IN_LEDOR', 'IN_ACESSO', 'IN_TRANSCRICAO', 'IN_LIBRAS', 'IN_TEMPO_ADICIONAL', 'IN_LEITURA_LABIAL', 'IN_MESA_CADEIRA_RODAS', 'IN_MESA_CADEIRA_SEPARADA', 'IN_APOIO_PERNA', 'IN_GUIA_INTERPRETE', 'IN_COMPUTADOR', 'IN_CADEIRA_ESPECIAL', 'IN_CADEIRA_CANHOTO', 'IN_CADEIRA_ACOLCHOADA', 'IN_PROVA_DEITADO', 'IN_MOBILIARIO_OBESO', 'IN_LAMINA_OVERLAY', 'IN_PROTETOR_AURICULAR', 'IN_MEDIDOR_GLICOSE', 'IN_MAQUINA_BRAILE', 'IN_SOROBAN', 'IN_MARCA_PASSO', 'IN_SONDA', 'IN_MEDICAMENTOS', 'IN_SALA_INDIVIDUAL', 'IN_SALA_ESPECIAL', 'IN_SALA_ACOMPANHANTE', 'IN_MOBILIARIO_ESPECIFICO', 'IN_MATERIAL_ESPECIFICO', 'IN_NOME_SOCIAL'], axis=1)
# Out:
#          NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# 396      190001005023    2019                  1503903
# 8425     190001013052    2019                  1302603
# 23344    190001027972    2019                  1302603
# 23348    190001027976    2019                  1302603
# 23349    190001027977    2019                  1302603
# ...               ...     ...                      ...
# 5094616  190006119542    2019                  1302603
# 5094621  190006119547    2019                  1302603
# 5094637  190006119563    2019                  1302603
# 5094638  190006119564    2019                  1302603
# 5094640  190006119566    2019                  1302603
#
#         NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 396                      Juruti                15               PA        17
# 8425                     Manaus                13               AM        18
# ...

# %%
# new_df = pd.DataFrame(df_manaus_small)
# new_df.to_csv('new_dataset_manaus.csv')

import pandas as pd
import numpy as np

# %%
new_manaus = pd.read_csv('new_dataset_manaus.csv',encoding='ISO-8859-1')
new_manaus = new_manaus.dropna().reset_index()
# new_manaus['NU_NOTA_REDACAO']
cols_manaus = new_manaus.columns.tolist()
save = []
for x in cols_manaus:
    save.append(x)
print(save)
# Out:
# ['index', 'Unnamed: 0', 'NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA', 'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA', 'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO', 'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ', 'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA', 'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL', 'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA', 'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE', 'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR', 'IN_SEM_RECURSO', 'IN_BRAILLE', 'IN_AMPLIADA_24', 'IN_AMPLIADA_18', 'IN_LEDOR', 'IN_ACESSO', 'IN_TRANSCRICAO', 'IN_LIBRAS', 'IN_TEMPO
# ...

# %%
df_manaus = new_manaus.copy()
df_manaus.drop(['NU_ANO', 'CO_MUNICIPIO_RESIDENCIA', 'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA', 'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO', 'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC','CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ', 'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA', 'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL', 'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA', 'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE', 'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR', 'IN_SEM_RECURSO', 'IN_BRAILLE', 'IN_AMPLIADA_24', 'IN_AMPLIADA_18', 'IN_LEDOR', 'IN_ACESSO', 'IN_TRANSCRICAO', 'IN_LIBRAS', 'IN_TEMPO_ADICIONAL', 'IN_LEITURA_LABIAL', 'IN_MESA_CADEIRA_RODAS', 'IN_MESA_CADEIRA_SEPARADA', 'IN_APOIO_PERNA', 'IN_GUIA_INTERPRETE', 'IN_COMPUTADOR', 'IN_CADEIRA_ESPECIAL', 'IN_CADEIRA_CANHOTO', 'IN_CADEIRA_ACOLCHOADA', 'IN_PROVA_DEITADO', 'IN_MOBILIARIO_OBESO', 'IN_LAMINA_OVERLAY', 'IN_PROTETOR_AURICULAR', 'IN_MEDIDOR_GLICOSE', 'IN_MAQUINA_BRAILE', 'IN_SOROBAN', 'IN_MARCA_PASSO', 'IN_SONDA', 'IN_MEDICAMENTOS', 'IN_SALA_INDIVIDUAL', 'IN_SALA_ESPECIAL', 'IN_SALA_ACOMPANHANTE', 'IN_MOBILIARIO_ESPECIFICO', 'IN_MATERIAL_ESPECIFICO', 'IN_NOME_SOCIAL', 'CO_MUNICIPIO_PROVA', 'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA', 'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT','TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH', 'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC', 'TX_GABARITO_MT','TP_STATUS_REDACAO','NU_NOTA_COMP1','NU_NOTA_COMP2','NU_NOTA_COMP3','NU_NOTA_COMP4','NU_NOTA_COMP5','Q001', 'Q002', 'Q003', 'Q004', 'Q005','Q007', 'Q008', 'Q009', 'Q010', 'Q011', 'Q012', 'Q013', 'Q014', 'Q015', 'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025'], axis='columns',inplace=True)

# %%
df_manaus
# Out:
#        index  Unnamed: 0  NU_INSCRICAO NO_MUNICIPIO_ESC  NU_NOTA_CN  \
# 0          0         396  190001005023           Manaus       400.7
# 1          1        8425  190001013052           Manaus       343.7
# 2          3       23348  190001027976           Manaus       376.6
# 3          5       23351  190001027979           Manaus       436.3
# 4          6       23357  190001027985           Manaus       454.8
# ...      ...         ...           ...              ...         ...
# 11891  16134     5094604  190006119530           Manaus       550.4
# 11892  16135     5094615  190006119541           Manaus       480.9
# 11893  16138     5094637  190006119563           Manaus       576.9
# 11894  16139     5094638  190006119564           Manaus       593.7
# 11895  16140     5094640  190006119566           Manaus       367.1
#
#        NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO Q006
# 0           350.9       440.7       444.1            420.0    A
# ...

# %%
#df_manaus_A = df_manaus[df_manaus['Q006'] == 'B']
df_manaus_A_B_C = df_manaus.loc[(df_manaus["Q006"]=="A") | (df_manaus["Q006"]=="B") | (df_manaus["Q006"]=="C")]
df_manaus_A_B_C["NOTA TOTAL"] = df_manaus_A_B_C.iloc[:,4:8].sum(axis=1)
save_A_B_C = []
for x in df_manaus_A_B_C["NOTA TOTAL"]:
    save_A_B_C.append(x)
arr_A_B_C = np.array(save_A_B_C)
print(type(arr_A_B_C))
# Out:
# <class 'numpy.ndarray'>
# /home/pcorrea/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
grafNormalized(df_manaus_A_B_C["NOTA TOTAL"],"nota final classe A, B e C")

# %%
checkNormalDistribution(df_manaus_A_B_C["NOTA TOTAL"])

# %%
intervConfianca(arr_A_B_C)
# Out:
# Intervalo de Confiança ao nível de 95% para média quando a variância é desconhecida
# Limite inferior 95%: 1881.69
# Limite superior 95%: 1891.027

# %%
df_manaus_acima = df_manaus.loc[(df_manaus["Q006"]=="D") | (df_manaus["Q006"]=="E") | (df_manaus["Q006"]=="F") | (df_manaus["Q006"]=="G") | (df_manaus["Q006"]=="H") | (df_manaus["Q006"]=="I") | (df_manaus["Q006"]=="F") | (df_manaus["Q006"]=="J") | (df_manaus["Q006"]=="K") | (df_manaus["Q006"]=="L") | (df_manaus["Q006"]=="M") | (df_manaus["Q006"]=="N") | (df_manaus["Q006"]=="O") | (df_manaus["Q006"]=="P") | (df_manaus["Q006"]=="Q")]
df_manaus_acima["SOMA TOTAL"] = df_manaus_acima.iloc[:,4:8].sum(axis=1)

save_acima = []
for x in df_manaus_acima["SOMA TOTAL"]:
    save_acima.append(x)
arr_acima = np.array(save_acima)
print(type(arr_acima))
# Out:
# <class 'numpy.ndarray'>
# /home/pcorrea/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
grafNormalized(df_manaus_acima["SOMA TOTAL"], "com renda acima")

# %%
checkNormalDistribution(df_manaus_acima["SOMA TOTAL"])

# %%
intervConfianca(arr_acima)
# Out:
# Intervalo de Confiança ao nível de 95% para média quando a variância é desconhecida
# Limite inferior 95%: 2079.88
# Limite superior 95%: 2096.658

# %%
from scipy.stats import f_oneway

# %%
_, p = f_oneway(arr_A_B_C, arr_acima)
p
# Out:
# 0.0

# %%
alpha = 0.01
if p <= alpha:
    print('Hipótese nula rejeitada')
else:
    print('Hipótese alternativa rejeitada')
# Out:
# Hipótese nula rejeitada

# %%
# !apt-get install libgeos-3.5.0
# !apt-get install libgeos-dev
# !pip install https://github.com/matplotlib/basemap/archive/master.zip
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\pcorrea\Anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\pcorrea\\AppData\\Local\\Temp\\pip-req-build-fluikz_v\\setup.py'"'"'; __file__='"'"'C:\\Users\\pcorrea\\AppData\\Local\\Temp\\pip-req-build-fluikz_v\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\pcorrea\AppData\Local\Temp\pip-pip-egg-info-7u4u5ezw'
#          cwd: C:\Users\pcorrea\AppData\Local\Temp\pip-req-build-fluikz_v\
#     Complete output (18 lines):
#     checking for GEOS lib in C:\Users\pcorrea ....
#     checking for GEOS lib in C:\Users\pcorrea\local ....
#     checking for GEOS lib in /usr ....
#     checking for GEOS lib in /usr/local ....
#     checking for GEOS lib in /sw ....
#     checking for GEOS lib in /opt ....
# ...

# %%
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-153-d9467465a3b6> in <module>
# ----> 1 from mpl_toolkits.basemap import Basemap
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
lat1 = df_manaus_inep['Latitude']
lon1 = df_manaus_inep['Longitude']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))

m = Basemap(projection='cyl', resolution='h',llcrnrlat = lat1,llcrnrlon = lon1)
m.drawcoastlines()
m.fillcontinents(color = 'palegoldenrod', lake_color='lightskyblue')
m.drawmapboundary(fill_color='lightskyblue')
m.scatter(df_manaus_inep['Longitude'], df_manaus_inep['Latitude'], s = 5, c = 'green', alpha = 0.1, zorder = 2)
# m.scatter(dataset_caros['long'], dataset_caros['lat'], s = 10, c = 'red', alpha = 0.1, zorder = 3)
# m.scatter(dataset_baratos['long'], dataset_baratos['lat'], s = 10, c = 'blue', alpha = 0.1, zorder = 4)
