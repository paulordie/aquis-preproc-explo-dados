# %% [markdown]
# #Especificação da Atividade 1

# %% [markdown]
# > Obter um novo Dataset de países a partir da **coleta** e **integração** de dados das seguintes fontes:
#
# > – Dataset0: https://restcountries.eu/
#
# > – Dataset1: flags.csv
#
# > – Dataset2: countries.csv
#
# > • Integrar a maior quantidade de informação possível.
#
# > • Criar um novo Dataset e guardar a informação num arquivo .csv

# %% [markdown]
# # Equipe

# %% [markdown]
# Everton - edss.cid20@uea.edu.br
#
# Maisa - mvt.cid20@uea.edu.br
#
# Paulo - pcdrc.cid20@uea.edu.br
#
# Thiago - tvdm.cid20@uea.edu.br

# %% [markdown]
# # Instalação de Pacotes

# %%
pip install python-restcountries
# Out:
# Requirement already satisfied: python-restcountries in /usr/local/lib/python3.6/dist-packages (0.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from python-restcountries) (0.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from python-restcountries) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->python-restcountries) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->python-restcountries) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->python-restcountries) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->python-restcountries) (2.10)

# %% [markdown]
# Um *wrapper* para a API de http://restcountries.eu <http://restcountries.eu>

# %% [markdown]
# # Importação de bibliotecas

# %%
import pandas as pd
from google.colab import files
from restcountries import RestCountryApiV2 as rapi

# %% [markdown]
# # Dataset0: https://restcountries.eu/

# %%
all_countries = rapi.get_all()

# %%
dataset0_restcountries = pd.DataFrame([country.__dict__ for country in all_countries])

# %%
dataset0_restcountries
# Out:
#     top_level_domain  ... cioc
# 0              [.af]  ...  AFG
# 1              [.ax]  ...
# 2              [.al]  ...  ALB
# 3              [.dz]  ...  ALG
# 4              [.as]  ...  ASA
# ..               ...  ...  ...
# 245            [.wf]  ...
# 246            [.eh]  ...
# 247            [.ye]  ...  YEM
# 248            [.zm]  ...  ZAM
# 249            [.zw]  ...  ZIM
#
# [250 rows x 25 columns]

# %% [markdown]
# # Dataset1: flags.csv

# %% [markdown]
# Primeiramente, faça *upload* do arquivo ***flags.csv*** para a pasta ***sample_data*** do colab.

# %%
dataset1_flags = pd.read_csv('sample_data/flags.csv',encoding= 'latin_1',sep=',')

# %%
dataset1_flags['name'] = dataset1_flags['name'].str.replace('-', ' ')

# %%
dataset1_flags
# Out:
#                name  landmass  zone  area  ...  animate  text  topleft  botright
# 0       Afghanistan         5     1   648  ...        0     0    black     green
# 1           Albania         3     1    29  ...        1     0      red       red
# 2           Algeria         4     1  2388  ...        0     0    green     white
# 3    American Samoa         6     3     0  ...        1     0     blue       red
# 4           Andorra         3     1     0  ...        0     0     blue       red
# ..              ...       ...   ...   ...  ...      ...   ...      ...       ...
# 189   Western Samoa         6     3     3  ...        0     0     blue       red
# 190      Yugoslavia         3     1   256  ...        0     0     blue       red
# 191           Zaire         4     2   905  ...        1     0    green     green
# 192          Zambia         4     2   753  ...        1     0    green     brown
# 193        Zimbabwe         4     2   391  ...        1     0    green     green
#
# [194 rows x 30 columns]

# %% [markdown]
# # Dataset2: countries.csv

# %% [markdown]
# Primeiramente, faça *upload* do arquivo ***countries.csv*** para a pasta ***sample_data*** do colab.

# %%
dataset2_countries = pd.read_csv('sample_data/countries.csv',encoding= 'latin_1',sep=';',na_values='null',keep_default_na=False)

# %%
dataset2_countries
# Out:
#     alpha_2 alpha_3  ...  postal_code_regex  tld,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 0        AD     AND  ...   ^(?:AD)*(\d{3})$   .ad,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 1        AE     ARE  ...                          .ae,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 2        AF     AFG  ...                             .af,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 3        AG     ATG  ...                     .ag,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 4        AI     AIA  ...                     .ai,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ..      ...     ...  ...                ...                                      ...
# 247      ZA     ZAF  ...          ^(\d{4})$                 .za,,,,,,,,,,,,,,,,,,,,,
# 248      ZM     ZMB  ...          ^(\d{5})$              .zm,,,,,,,,,,,,,,,,,,,,,,,,
# 249      ZW     ZWE  ...                           .zw,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 250      CS     SCG  ...          ^(\d{5})$           .cs,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 251      AN     ANT  ...                       .an,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# [252 rows x 19 columns]

# %% [markdown]
# # Integração dos Datasets

# %%
paises_somente_df_countries = dataset2_countries[dataset2_countries.alpha_2.isin(dataset0_restcountries.alpha2_code)==False]

# %%
paises_somente_df_countries
# Out:
#     alpha_2 alpha_3  ...  postal_code_regex tld,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 250      CS     SCG  ...          ^(\d{5})$          .cs,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 251      AN     ANT  ...                      .an,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# [2 rows x 19 columns]

# %% [markdown]
# OBS: **Os dois países a mais no dataset 'countries.csv' em relaçao ao dataset 'restcountries' já não existem mais.**

# %%
paises_somente_df_restcoun = dataset0_restcountries[dataset0_restcountries.alpha2_code.isin(dataset2_countries.alpha_2)==False]

# %%
paises_somente_df_restcoun
# Out:
# Empty DataFrame
# Columns: [top_level_domain, alpha2_code, alpha3_code, currencies, capital, calling_codes, alt_spellings, relevance, region, subregion, translations, population, latlng, demonym, area, gini, timezones, borders, native_name, name, numeric_code, languages, flag, regional_blocs, cioc]
# Index: []

# %%
dataset0_e_dataset2 = pd.merge(dataset0_restcountries,dataset2_countries, how="left",left_on="alpha2_code",right_on="alpha_2")

# %%
dataset0_e_dataset2
# Out:
#     top_level_domain  ...  tld,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 0              [.af]  ...          .af,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 1              [.ax]  ...  .ax,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 2              [.al]  ...       .al,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 3              [.dz]  ...        .dz,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 4              [.as]  ...    .as,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ..               ...  ...                                      ...
# 245            [.wf]  ...    .wf,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 246            [.eh]  ...     .eh,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 247            [.ye]  ...   .ye,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# 248            [.zm]  ...              .zm,,,,,,,,,,,,,,,,,,,,,,,,
# 249            [.zw]  ...        .zw,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# [250 rows x 44 columns]

# %%
all_datasets = pd.merge(dataset0_e_dataset2,dataset1_flags,how="left",left_on="name_x",right_on="name")

# %%
all_datasets
# Out:
#     top_level_domain alpha2_code alpha3_code  ... text topleft botright
# 0              [.af]          AF         AFG  ...  0.0   black    green
# 1              [.ax]          AX         ALA  ...  NaN     NaN      NaN
# 2              [.al]          AL         ALB  ...  0.0     red      red
# 3              [.dz]          DZ         DZA  ...  0.0   green    white
# 4              [.as]          AS         ASM  ...  0.0    blue      red
# ..               ...         ...         ...  ...  ...     ...      ...
# 245            [.wf]          WF         WLF  ...  NaN     NaN      NaN
# 246            [.eh]          EH         ESH  ...  NaN     NaN      NaN
# 247            [.ye]          YE         YEM  ...  NaN     NaN      NaN
# 248            [.zm]          ZM         ZMB  ...  0.0   green    brown
# 249            [.zw]          ZW         ZWE  ...  0.0   green    green
#
# [250 rows x 74 columns]

# %% [markdown]
# # Download para CSV do novo dataset

# %%
all_datasets.to_csv("new_dataset.csv", index=False)
files.download("new_dataset.csv")

# %% [markdown]
# # Leitura do novo dataset a partir de arquivo CVS

# %%
new_dataset = pd.read_csv('new_dataset.csv',encoding= 'utf8',sep=',',na_values='null',keep_default_na=False)

# %%
new_dataset
# Out:
#     top_level_domain alpha2_code alpha3_code  ... text topleft botright
# 0            ['.af']          AF         AFG  ...  0.0   black    green
# 1            ['.ax']          AX         ALA  ...
# 2            ['.al']          AL         ALB  ...  0.0     red      red
# 3            ['.dz']          DZ         DZA  ...  0.0   green    white
# 4            ['.as']          AS         ASM  ...  0.0    blue      red
# ..               ...         ...         ...  ...  ...     ...      ...
# 245          ['.wf']          WF         WLF  ...
# 246          ['.eh']          EH         ESH  ...
# 247          ['.ye']          YE         YEM  ...
# 248          ['.zm']          ZM         ZMB  ...  0.0   green    brown
# 249          ['.zw']          ZW         ZWE  ...  0.0   green    green
#
# [250 rows x 74 columns]
